# %% [markdown]
# **slicing(Strat: stop:step)**

# %%
#indexing[]
institute = "Edukron"
print(institute[0])
print(institute[1])
            #0123456
            #-7-6-5-4-3-2-1
# Out:
# E
# d

# %%
for index, letter in enumerate(institute):
    print(f"Letter '{letter}' is at position {index}")
# Out:
# Letter 'E' is at position 0
# Letter 'd' is at position 1
# Letter 'u' is at position 2
# Letter 'k' is at position 3
# Letter 'r' is at position 4
# Letter 'o' is at position 5
# Letter 'n' is at position 6

# %%
for index , letter in enumerate(institute):
  print(f"Leter '{letter} is at position {index}")
# Out:
# Leter 'E is at position 0
# Leter 'd is at position 1
# Leter 'u is at position 2
# Leter 'k is at position 3
# Leter 'r is at position 4
# Leter 'o is at position 5
# Leter 'n is at position 6

# %%
len(institute)
tech_stack = "Azure DevOps and Python"
first_5=tech_stack[0:5]
print(first_5)
# Out:
# Azure

# %%
middle=tech_stack[1:-1]
print(middle)
# Out:
# zure DevOps and Pytho
