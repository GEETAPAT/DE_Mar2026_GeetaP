# %% [markdown]
# **list data type**

# %% [markdown]
# **list data type**
#
# In Python, a **list** is a versatile and commonly used data structure that allows you to store an ordered collection of items. Lists are:
#
# *   **Ordered**: The items maintain a specific order, and this order will not change unless explicitly modified.
# *   **Changeable (Mutable)**: You can add, remove, or modify elements after the list has been created.
# *   **Allow Duplicates**: Lists can contain multiple items with the same value.
# *   **Heterogeneous**: A single list can contain items of different data types (e.g., integers, strings, floats, other lists).
#
# Lists are defined by enclosing comma-separated items within square brackets `[]`.

# %%
my_list=[1,2,3,4,"banana","apple","pinapple"]
print(f"values stored in my_list: {my_list[0]}")
my_list.append("orange")
print(f"values added to my_list: {my_list}")
my_list.remove("banana")
print(f"values removed from my_list: {my_list}")
# Out:
# values stored in my_list: 1
# values added to my_list: [1, 2, 3, 4, 'banana', 'apple', 'pinapple', 'orange']
# values removed from my_list: [1, 2, 3, 4, 'apple', 'pinapple', 'orange']

# %%
print(my_list[0:4])
print(my_list[3:6])
print(my_list[0::6])

print(my_list[::6])
print('---------')
print(my_list[::-2])
print('----------------------')
print(my_list[-1:-2:-1])
# Out:
# [1, 2, 3, 4]
# [4, 'apple', 'pinapple']
# [1, 'orange']
# [1, 'orange']
# ---------
# ['orange', 'apple', 3, 1]
# ----------------------
# ['orange']

# %%
print(my_list[3])
# Out:
# 4

# %%
my_nested_list =[1,2,[3,4],["apple","orrange"]]
print(my_nested_list[3])
# Out:
# ['apple', 'orrange']

# %%
# Creating a list
my_list = [1, 2, 3, "apple", "banana", 3.14]
print(f"Original list: {my_list}")

# Accessing elements (lists are zero-indexed)
print(f"First element: {my_list[0]}")
print(f"Last element: {my_list[-1]}")

# Slicing a list
print(f"Elements from index 1 to 3 (exclusive): {my_list[1:4]}")

# Modifying elements
my_list[0] = 100
print(f"List after modifying first element: {my_list}")

# Adding elements
my_list.append("orange") # Add to the end
print(f"List after appending 'orange': {my_list}")
my_list.insert(1, "grape") # Insert at a specific index
print(f"List after inserting 'grape' at index 1: {my_list}")

# Removing elements
my_list.remove("banana") # Remove by value
print(f"List after removing 'banana': {my_list}")
popped_item = my_list.pop() # Remove and return the last element
print(f"List after popping last element ('{popped_item}'): {my_list}")
del my_list[0] # Delete by index
print(f"List after deleting first element: {my_list}")

# Checking if an item exists
print(f"Is 'apple' in the list? {'apple' in my_list}")

# Length of the list
print(f"Length of the list: {len(my_list)}")

# Iterating through a list
print("Iterating through the list:")
for item in my_list:
    print(item)
